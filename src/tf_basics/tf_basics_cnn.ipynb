# %%
# imports
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)

print('x train, test, val shape : ', x_train.shape, x_test.shape, x_val.shape)
print('y train, test, val shape : ', y_train.shape, y_test.shape, y_val.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# x train, test, val shape :  (37500, 32, 32, 3) (10000, 32, 32, 3) (12500, 32, 32, 3)
# y train, test, val shape :  (37500, 1) (10000, 1) (12500, 1)

# %%
# Normalization and convertion of datatype.
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0
x_val = x_val.astype(np.float32) / 255.0

# %%
# Visualization of one of the image label pairs.
plt.title(y_train[1])
plt.imshow(x_train[1])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
# Simple CNN model with maxpooling

# If padding is set to valid, its the default (i.e no padding)
# If padding is set to same, the image dimensions remain unchanged.

cnn_model = tf.keras.Sequential([
    tf.keras.Input(shape=(32,32,3), name="input_layer"),
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding='same', activation='relu', name="conv_2d_1"),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2), name="max_pooling_1"),
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same', activation='relu', name="conv_2d_2"),
    tf.keras.layers.MaxPooling2D(pool_size=(2,2), name="max_pooling_2"),
    tf.keras.layers.Flatten(name='flattening_layer'),
    tf.keras.layers.Dense(32, activation='relu', name='dense_1'),
    tf.keras.layers.Dense(10, activation='softmax', name='dense_2'),
])

cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_2d_1 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling_1 (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv_2d_2 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling_2 (MaxPooling2  (None, 8, 8, 64)          0
#  D)
#
#  flattening_layer (Flatten)  (None, 4096)              0
#
#  dense_1 (Dense)             (None, 32)                131104
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 150826 (589.16 KB)
# Trainable params: 150826 (589.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn_model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'],
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001)
)

# %%
def train_eval_plot_model(model, x_train, x_test, x_val, y_train, y_test, y_val):
  history = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_val, y_val))

  epochs = range(0, len(history.history['loss']))
  plt.title('training vs validation loss')
  plt.xlabel('epochs')
  plt.ylabel('loss')
  plt.plot(epochs, history.history['loss'], 'r', label="training loss")
  plt.plot(epochs, history.history['val_loss'], 'g', label="validation loss")
  plt.legend()
  plt.show()

  plt.title('training vs validation accuracy')
  plt.xlabel('epochs')
  plt.ylabel('accuracy')
  plt.plot(epochs, history.history['accuracy'], 'r', label="training accuracy")
  plt.plot(epochs, history.history['val_accuracy'], 'g', label="validation accuracy")
  plt.legend()
  plt.show()

  print('model evaluation on testing data')
  print(model.evaluate(x_test, y_test))

# %%
train_eval_plot_model(cnn_model, x_train, x_test, x_val, y_train, y_test, y_val)
# Out:
# Epoch 1/5
# 1172/1172 [==============================] - 6s 5ms/step - loss: 1.2297 - accuracy: 0.5610 - val_loss: 1.1872 - val_accuracy: 0.5804
# Epoch 2/5
# 1172/1172 [==============================] - 6s 5ms/step - loss: 1.0924 - accuracy: 0.6104 - val_loss: 1.0480 - val_accuracy: 0.6296
# Epoch 3/5
# 1172/1172 [==============================] - 5s 4ms/step - loss: 0.9984 - accuracy: 0.6483 - val_loss: 1.0121 - val_accuracy: 0.6446
# Epoch 4/5
# 1172/1172 [==============================] - 6s 5ms/step - loss: 0.9276 - accuracy: 0.6731 - val_loss: 1.0058 - val_accuracy: 0.6435
# Epoch 5/5
# 1172/1172 [==============================] - 5s 5ms/step - loss: 0.8739 - accuracy: 0.6916 - val_loss: 0.9786 - val_accuracy: 0.6571
# model evaluation on testing data
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9818 - accuracy: 0.6545
# [0.9818007946014404, 0.6545000076293945]

# %%
tf.keras.losses.SparseCategoricalCrossentropy?

# %%
# Using the functional API with batch normalization.
def func_model():
    input = tf.keras.Input(shape=(32,32,3), name="input_layer")
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding='same',  kernel_regularizer=tf.keras.regularizers.L2(0.01), name="conv_2d_1")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2), name="max_pooling_1")(x)
    x = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), strides=1, padding='same', kernel_regularizer=tf.keras.regularizers.L2(0.01), name="conv_2d_2")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), strides=1, padding='same',  kernel_regularizer=tf.keras.regularizers.L2(0.01), name="conv_2d_3")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2,2), name="max_pooling_2")(x)
    x = tf.keras.layers.Flatten(name='flattening_layer')(x)
    x = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.01), name='dense_1')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    output = tf.keras.layers.Dense(10, name='output_layer')(x)

    model = tf.keras.Model(inputs=input, outputs=output)

    print(model.summary())
    return model

model = func_model()
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01)
)
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 32, 32, 3)]       0
#
#  conv_2d_1 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_50 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  tf.nn.relu_49 (TFOpLambda)  (None, 32, 32, 32)        0
#
#  max_pooling_1 (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv_2d_2 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_51 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  tf.nn.relu_50 (TFOpLambda)  (None, 16, 16, 64)        0
#
#  conv_2d_3 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_52 (Ba  (None, 16, 16, 128)       512
#  tchNormalization)
#
#  tf.nn.relu_51 (TFOpLambda)  (None, 16, 16, 128)       0
#
#  max_pooling_2 (MaxPooling2  (None, 8, 8, 128)         0
#  D)
#
#  flattening_layer (Flatten)  (None, 8192)              0
#
#  dense_1 (Dense)             (None, 32)                262176
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  output_layer (Dense)        (None, 10)                330
#
# =================================================================
# Total params: 356650 (1.36 MB)
# Trainable params: 356202 (1.36 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________
# None

# %%
train_eval_plot_model(model, x_train, x_test, x_val, y_train, y_test, y_val)
# Out:
# Epoch 1/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 2.1114 - accuracy: 0.2214 - val_loss: 1.8976 - val_accuracy: 0.3102
# Epoch 2/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 2.0129 - accuracy: 0.2539 - val_loss: 1.8084 - val_accuracy: 0.3686
# Epoch 3/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.9374 - accuracy: 0.2924 - val_loss: 1.6746 - val_accuracy: 0.4544
# Epoch 4/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.8641 - accuracy: 0.3209 - val_loss: 2.0691 - val_accuracy: 0.2930
# Epoch 5/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.8125 - accuracy: 0.3429 - val_loss: 1.9050 - val_accuracy: 0.4279
# Epoch 6/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7925 - accuracy: 0.3529 - val_loss: 1.8645 - val_accuracy: 0.3142
# Epoch 7/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7700 - accuracy: 0.3635 - val_loss: 1.7180 - val_accuracy: 0.4267
# Epoch 8/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7707 - accuracy: 0.3642 - val_loss: 1.5885 - val_accuracy: 0.4963
# Epoch 9/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7605 - accuracy: 0.3736 - val_loss: 1.6745 - val_accuracy: 0.4618
# Epoch 10/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7552 - accuracy: 0.3753 - val_loss: 2.0208 - val_accuracy: 0.2954
# Epoch 11/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7540 - accuracy: 0.3791 - val_loss: 1.5418 - val_accuracy: 0.5412
# Epoch 12/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7463 - accuracy: 0.3804 - val_loss: 2.2675 - val_accuracy: 0.3922
# Epoch 13/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7499 - accuracy: 0.3819 - val_loss: 1.4778 - val_accuracy: 0.5596
# Epoch 14/50
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.7387 - accuracy: 0.3831 - val_loss: 1.8094 - val_accuracy: 0.4780
# Epoch 15/50
# 1172/1172 [==============================] - 6s 6ms/step - loss: 1.7378 - accuracy: 0.3875 - val_loss: 1.6813 - val_accuracy: 0.4703
# Epoch 16/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7513 - accuracy: 0.3841 - val_loss: 1.7534 - val_accuracy: 0.4515
# Epoch 17/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7276 - accuracy: 0.3965 - val_loss: 1.6015 - val_accuracy: 0.4613
# Epoch 18/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7363 - accuracy: 0.3922 - val_loss: 1.7836 - val_accuracy: 0.4222
# Epoch 19/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7288 - accuracy: 0.3933 - val_loss: 1.7311 - val_accuracy: 0.4303
# Epoch 20/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7296 - accuracy: 0.3989 - val_loss: 1.6534 - val_accuracy: 0.4754
# Epoch 21/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7287 - accuracy: 0.3981 - val_loss: 1.7040 - val_accuracy: 0.4098
# Epoch 22/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7151 - accuracy: 0.4028 - val_loss: 1.5237 - val_accuracy: 0.5312
# Epoch 23/50
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.7218 - accuracy: 0.3999 - val_loss: 2.0365 - val_accuracy: 0.3201
# Epoch 24/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7192 - accuracy: 0.4039 - val_loss: 1.7554 - val_accuracy: 0.4396
# Epoch 25/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7284 - accuracy: 0.3990 - val_loss: 1.7520 - val_accuracy: 0.4310
# Epoch 26/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7157 - accuracy: 0.4031 - val_loss: 1.9381 - val_accuracy: 0.3850
# Epoch 27/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7206 - accuracy: 0.4019 - val_loss: 1.8563 - val_accuracy: 0.4406
# Epoch 28/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7043 - accuracy: 0.4094 - val_loss: 1.4856 - val_accuracy: 0.5621
# Epoch 29/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7133 - accuracy: 0.4043 - val_loss: 2.6868 - val_accuracy: 0.3321
# Epoch 30/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7226 - accuracy: 0.4045 - val_loss: 1.8056 - val_accuracy: 0.3838
# Epoch 31/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7160 - accuracy: 0.4093 - val_loss: 1.5530 - val_accuracy: 0.5218
# Epoch 32/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7087 - accuracy: 0.4092 - val_loss: 1.7056 - val_accuracy: 0.4734
# Epoch 33/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7167 - accuracy: 0.4084 - val_loss: 1.5497 - val_accuracy: 0.5268
# Epoch 34/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7060 - accuracy: 0.4093 - val_loss: 1.5646 - val_accuracy: 0.5338
# Epoch 35/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7108 - accuracy: 0.4139 - val_loss: 1.5227 - val_accuracy: 0.5294
# Epoch 36/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7090 - accuracy: 0.4112 - val_loss: 1.5930 - val_accuracy: 0.5197
# Epoch 37/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7078 - accuracy: 0.4145 - val_loss: 1.6396 - val_accuracy: 0.5222
# Epoch 38/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7139 - accuracy: 0.4123 - val_loss: 1.7204 - val_accuracy: 0.4253
# Epoch 39/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7099 - accuracy: 0.4095 - val_loss: 1.7101 - val_accuracy: 0.4105
# Epoch 40/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7016 - accuracy: 0.4149 - val_loss: 2.4494 - val_accuracy: 0.2886
# Epoch 41/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7116 - accuracy: 0.4114 - val_loss: 1.5798 - val_accuracy: 0.5186
# Epoch 42/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7037 - accuracy: 0.4154 - val_loss: 1.7529 - val_accuracy: 0.4673
# Epoch 43/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7019 - accuracy: 0.4130 - val_loss: 1.4669 - val_accuracy: 0.5543
# Epoch 44/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7069 - accuracy: 0.4095 - val_loss: 1.7766 - val_accuracy: 0.4654
# Epoch 45/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.7022 - accuracy: 0.4174 - val_loss: 1.4996 - val_accuracy: 0.5382
# Epoch 46/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7096 - accuracy: 0.4125 - val_loss: 1.8852 - val_accuracy: 0.4373
# Epoch 47/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.6961 - accuracy: 0.4194 - val_loss: 1.6453 - val_accuracy: 0.4978
# Epoch 48/50
# 1172/1172 [==============================] - 8s 7ms/step - loss: 1.6900 - accuracy: 0.4205 - val_loss: 2.1380 - val_accuracy: 0.3528
# Epoch 49/50
# 1172/1172 [==============================] - 7s 6ms/step - loss: 1.6994 - accuracy: 0.4167 - val_loss: 1.5594 - val_accuracy: 0.5360
# Epoch 50/50
# 1172/1172 [==============================] - 8s 6ms/step - loss: 1.7036 - accuracy: 0.4183 - val_loss: 1.7548 - val_accuracy: 0.4431
# model evaluation on testing data
# 313/313 [==============================] - 1s 3ms/step - loss: 1.7608 - accuracy: 0.4325
# [1.7607933282852173, 0.4325000047683716]
