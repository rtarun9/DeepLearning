# %%
import tensorflow as tf
import tensorflow.keras as keras

# %%
# Method 1 : from keras
help(keras.datasets)
# Out:
# Help on package keras.api._v2.keras.datasets in keras.api._v2.keras:
#
# NAME
#     keras.api._v2.keras.datasets - AUTOGENERATED. DO NOT EDIT.
#
# PACKAGE CONTENTS
#     boston_housing (package)
#     cifar10 (package)
#     cifar100 (package)
#     fashion_mnist (package)
#     imdb (package)
#     mnist (package)
#     reuters (package)
#
# FILE
#     c:\users\tarun\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages\keras\api\_v2\keras\datasets\__init__.py

# %%
# Method 2: from url
keras.utils.get_file?
# Out:
# Signature:
# keras.utils.get_file(
#     fname=None,
#     origin=None,
#     untar=False,
#     md5_hash=None,
#     file_hash=None,
#     cache_subdir='datasets',
#     hash_algorithm='auto',
#     extract=False,
#     archive_format='auto',
#     cache_dir=None,
# )
# Docstring:
# Downloads a file from a URL if it not already in the cache.
#
# By default the file at the url `origin` is downloaded to the
# cache_dir `~/.keras`, placed in the cache_subdir `datasets`,
# and given the filename `fname`. The final location of a file
# `example.txt` would therefore be `~/.keras/datasets/example.txt`.
#
# Files in tar, tar.gz, tar.bz, and zip formats can also be extracted.
# Passing a hash will verify the file after download. The command line
# programs `shasum` and `sha256sum` can compute the hash.
#
# Example:
#
# ```python
# path_to_downloaded_file = tf.keras.utils.get_file(
#     origin="https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz",
# ...

# %%
path_to_download_file = keras.utils.get_file('titanic.csv',   'https://storage.googleapis.com/tf-datasets/titanic/train.csv') 

data_train = tf.data.experimental.make_csv_dataset?
data_train = tf.data.experimental.make_csv_dataset(path_to_download_file, label_name='survived', batch_size=10, num_epochs=1, ignore_errors=True)
# Out:
# WARNING:tensorflow:From C:\Users\Tarun\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\data\experimental\ops\readers.py:573: ignore_errors (from tensorflow.python.data.experimental.ops.error_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.ignore_errors` instead.
# Signature:
# tf.data.experimental.make_csv_dataset(
#     file_pattern,
#     batch_size,
#     column_names=None,
#     column_defaults=None,
#     label_name=None,
#     select_columns=None,
#     field_delim=',',
#     use_quote_delim=True,
#     na_value='',
#     header=True,
#     num_epochs=None,
#     shuffle=True,
#     shuffle_buffer_size=10000,
#     shuffle_seed=None,
#     prefetch_buffer_size=None,
#     num_parallel_reads=None,
#     sloppy=False,
#     num_rows_for_inference=100,
#     compression_type=None,
#     ignore_errors=False,
# ...

# %%
for batch, label in data_train.take(1): 
    for key, value in batch.items(): 
        print(f"{key:10s}: {value}")
# Out:
# sex       : [b'male' b'male' b'female' b'female' b'male' b'female' b'male' b'female'
#  b'male' b'male']
# age       : [28.   28.   28.   17.   28.   18.   28.   40.   44.    0.83]
# n_siblings_spouses: [0 0 0 4 0 0 0 1 0 0]
# parch     : [0 0 0 2 0 0 0 1 0 2]
# fare      : [ 8.05   13.     13.      7.925   0.      9.8417  7.8292 39.      7.925
#  29.    ]
# class     : [b'Third' b'Second' b'Second' b'Third' b'First' b'Third' b'Third'
#  b'Second' b'Third' b'Second']
# deck      : [b'unknown' b'unknown' b'unknown' b'unknown' b'B' b'unknown' b'unknown'
#  b'unknown' b'unknown' b'unknown']
# embark_town: [b'Southampton' b'Southampton' b'Southampton' b'Southampton'
#  b'Southampton' b'Southampton' b'Queenstown' b'Southampton' b'Southampton'
#  b'Southampton']
# alone     : [b'y' b'y' b'y' b'n' b'y' b'y' b'y' b'n' b'y' b'n']

# %%
# Other method (Better way) to get data from internet. Can also be used to read local data.
import pandas as pd

abalone_train = pd.read_csv(
    "https://storage.googleapis.com/download.tensorflow.org/data/abalone_train.csv",
    names=["Length", "Diameter", "Height", "Whole weight", "Shucked weight",
           "Viscera weight", "Shell weight", "Age"])

# %%
abalone_train.columns
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Age'],
#       dtype='object')

# %%
import numpy as np

abalone_features = abalone_train.copy()
labels = abalone_features.pop('Age')

# %%
# Here we took all featuers as one large array : Our test data. 
abalone_features = np.array(abalone_features)

# %%
model = tf.keras.Sequential([
  keras.layers.Dense(64, activation='relu'),
  keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse',  metrics=['accuracy'])
model.fit(features, labels, epochs=20)
# Out:
# Epoch 1/20
# 104/104 [==============================] - 1s 1ms/step - loss: 42.6640 - accuracy: 0.0000e+00
# Epoch 2/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.3847 - accuracy: 3.0120e-04
# Epoch 3/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 3.0120e-04
# Epoch 4/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.1909 - accuracy: 3.0120e-04
# Epoch 5/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.1561 - accuracy: 3.0120e-04
# Epoch 6/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.1253 - accuracy: 3.0120e-04
# Epoch 7/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.0989 - accuracy: 3.0120e-04
# Epoch 8/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.0772 - accuracy: 3.0120e-04
# Epoch 9/20
# 104/104 [==============================] - 0s 1ms/step - loss: 0.0590 - accuracy: 3.0120e-04
# Epoch 10/20
# ...
